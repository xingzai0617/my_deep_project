# %%
# ========读取原始数据========
with open('cmn.txt', 'r', encoding='utf-8') as f:
    data = f.read()
data = data.split('\n')
data = data[:1000]
print(data[-5:])


# 分割英文数据和中文数据
en_data = [line.split('\t')[0] for line in data]
ch_data = [line.split('\t')[1] for line in data]
print('英文数据:\n', en_data[:10])
print('\n中文数据:\n', ch_data[:10])
# Out:
# ["I don't want it.\t我不要.", 'I feel relieved.\t我感觉轻松了。', 'I get up at six.\t我六點起床。', 'I had no choice.\t那时我没有选择的余地。', 'I hate studying.\t我讨厌学习。']
# 英文数据:
#  ['Hi.', 'Hi.', 'Run.', 'Wait!', 'Hello!', 'I try.', 'I won!', 'Oh no!', 'Cheers!', 'He ran.']
#
# 中文数据:
#  ['嗨。', '你好。', '你用跑的。', '等等！', '你好。', '让我来。', '我赢了。', '不会吧。', '乾杯!', '他跑了。']

# %%
# 特殊字符
SOURCE_CODES = ['<PAD>', '<UNK>']
TARGET_CODES = ['<PAD>', '<EOS>', '<UNK>', '<GO>']  # 在target中，需要增加<GO>与<EOS>特殊字符

# 分别生成中英文字典
en_vocab = set(''.join(en_data))
id2en = SOURCE_CODES + list(en_vocab)
en2id = {c:i for i,c in enumerate(id2en)}

# 分别生成中英文字典
ch_vocab = set(''.join(ch_data))
id2ch = TARGET_CODES + list(ch_vocab)
ch2id = {c:i for i,c in enumerate(id2ch)}

print('\n英文字典:\n', en2id)
print('\n中文字典共计\n:', ch2id)
# Out:
# 英文字典:
#  {'<PAD>': 0, '<UNK>': 1, 'x': 2, 'b': 3, 'v': 4, '!': 5, '7': 6, 'M': 7, 'c': 8, '0': 9, 'R': 10, 't': 11, 'k': 12, 'y': 13, '1': 14, ' ': 15, 'z': 16, 'P': 17, 'E': 18, 'F': 19, ',': 20, 'e': 21, 'h': 22, 'D': 23, 'I': 24, 'W': 25, 's': 26, 'm': 27, 'G': 28, 'i': 29, 'Y': 30, '8': 31, 'f': 32, 'J': 33, 'q': 34, 'V': 35, 'U': 36, 'C': 37, ':': 38, 'o': 39, 'r': 40, 'Q': 41, '.': 42, 'w': 43, 'N': 44, 'K': 45, 'S': 46, 'n': 47, 'B': 48, 'H': 49, 'O': 50, 'T': 51, 'a': 52, 'd': 53, 'j': 54, 'l': 55, '?': 56, '3': 57, 'L': 58, 'A': 59, 'p': 60, 'g': 61, "'": 62, 'u': 63}
#
# 中文字典共计
# : {'<PAD>': 0, '<EOS>': 1, '<UNK>': 2, '<GO>': 3, '抗': 4, '會': 5, '糟': 6, '尝': 7, '我': 8, '密': 9, '!': 10, '没': 11, '疯': 12, '續': 13, '掃': 14, '說': 15, '孤': 16, '瑪': 17, '相': 18, '埋': 19, '需': 20, '時': 21, '路': 22, '闭': 23, '结': 24, '脱': 25, '錢': 26, '信': 27, 'D': 28, '學': 29, '三': 30, '开': 31, '燃': 32, '斯': 33, '量': 34, '欠': 35, '危': 36, '呢': 37, '么': 38, '貪': 39, '矮': 40, '幹': 41, '露': 42, '缺': 43, '识': 44, '午': 45, '溜': 46, '作': 47, '光': 48, '命': 49, '生': 50, '遗': 51, '吸': 52, '棄': 53, '间': 54, '意': 55, '姆': 56, '门': 57, '還': 58, '害': 59, '跳': 60, '时': 61, '波': 62, '該': 63, '英': 64, '辱': 65, '认': 66, '别': 67, '婪': 68, '疲': 69, '郵': 70, '神': 71, '蒼': 72, '飽': 73, '默': 74, '應': 75, '尽': 76, '世': 77, '佬': 78, '帳': 79, '花': 80, '玫': 81, '8': 82, '失': 83, '确': 84, '塗': 85, '合': 86, '首': 87, '就': 88, '須': 89, '单': 90, '评': 91, '聊': 92, '抵': 93, '幫': 94, '孕': 95, '赌': 96, '惧': 97, '奇': 98, '騙': 99, '抱': 100, '聽': 101, '拯': 102, '欣': 103, '右': 104, '能': 105, '叫': 106, '地': 107, '头': 108, '怪': 109, '白': 110, '鬆': 111, '酒': 112, '箱': 113, '校': 114, '3': 115, '小': 116, '话': 117, '科': 118, '想': 119, '對': 120, '货': 121, '饱': 122, '鸟': 123, '乐': 124, '员': 125, '醒': 126, '响': 127, '始': 128, '禁': 129, '被': 130, '蛋': 131, 't': 132, '嗨': 133, '搞': 134, '铃': 135, '快': 136, '报': 137, '迷': 138, '色': 139, '闷': 140, 'e': 141, '衬': 142, '饭': 143, '醉': 144, '逮': 145, '價': 146, '誤': 147, '啊': 148, '朋': 149, '过': 150, '许': 151, '圖': 152, '管': 153, '參': 154, '几': 155, '待': 156, '樣': 157, '伙': 158, '張': 159, '空': 160, '.': 161, '魂': 162, '乎': 163, '諒': 164, '忙': 165, '趴': 166, '取': 167, '偷': 168, '什': 169, '茶': 170, '開': 171, '動': 172, '顾': 173, '责': 174, '让': 175, '腾': 176, '罪': 177, '嘴': 178, '?': 179, '現': 180, '每': 181, '晚': 182, '講': 183, '联': 184, '迎': 185, '自': 186, '無': 187, '楚': 188, '服': 189, '候': 190, '師': 191, '动': 192, '婚': 193, '起': 194, '公': 195, '刚': 196, '工': 197, '今': 198, '善': 199, '愿': 200, '万': 201, '现': 202, '燒': 203, '魚': 204, '通': 205, '谁': 206, '星': 207, 'i': 208, '问': 209, '们': 210, '觉': 211, '瘋': 212, '友': 213, '離': 214, '變': 215, '長': 216, '蠢': 217, '擊': 218, '明': 219, '慢': 220, '向': 221, '转': 222, '器': 223, '磁': 224, '旗': 225, '鲜': 226, '贏': 227, '難': 228, '嘗': 229, '升': 230, '武': 231, '浮': 232, '！': 233, '付': 234, '谦': 235, '应': 236, '味': 237, '勇': 238, '做': 239, '耐': 240, '继': 241, '聰': 242, '哈': 243, '还': 244, '頓': 245, '飯': 246, '往': 247, '音': 248, '給': 249, '在': 250, '止': 251, '学': 252, '烧': 253, 'm': 254, '丽': 255, '車': 256, '種': 257, '解': 258, '愚': 259, '恭': 260, '閉': 261, '愛': 262, '后': 263, '眉': 264, '放': 265, '诉': 266, 'r': 267, '羡': 268, '都': 269, '备': 270, '畏': 271, '兒': 272, '找': 273, '赢': 274, '影': 275, '欺': 276, '无': 277, '射': 278, '示': 279, '絕': 280, '歲': 281, '斷': 282, '手': 283, '興': 284, '必': 285, '乾': 286, '饿': 287, '台': 288, '干': 289, '的': 290, '掉': 291, '試': 292, '面': 293, '望': 294, '傻': 295, '月': 296, '業': 297, '識': 298, '船': 299, '弃': 300, '理': 301, '哪': 302, '按': 303, '獨': 304, '送': 305, '糖': 306, '老': 307, 'o': 308, '车': 309, '完': 310, '多': 311, '证': 312, '遠': 313, '托': 314, '独': 315, '语': 316, '嗎': 317, '运': 318, '汤': 319, '怨': 320, '辦': 321, '遇': 322, '咳': 323, '持': 324, '赶': 325, '煩': 326, '任': 327, '烟': 328, '床': 329, '活': 330, '美': 331, '飛': 332, '糕': 333, '经': 334, '湯': 335, '热': 336, '如': 337, '搅': 338, '请': 339, '迟': 340, '虚': 341, '压': 342, '站': 343, '前': 344, '們': 345, '归': 346, '而': 347, '歌': 348, '游': 349, '眼': 350, '使': 351, '目': 352, '漂': 353, '脚': 354, '辆': 355, '数': 356, '個': 357, 'w': 358, '从': 359, '慌': 360, '餐': 361, '敢': 362, '亡': 363, '疼': 364, '助': 365, '立': 366, '母': 367, '以': 368, '過': 369, '厌': 370, '贺': 371, '匈': 372, '雨': 373, '身': 374, '阅': 375, '淹': 376, '图': 377, '视': 378, '须': 379, '當': 380, '太': 381, '警': 382, '士': 383, '謊': 384, '胖': 385, '博': 386, '人': 387, ' ': 388, '丢': 389, '轻': 390, '正': 391, '鑰': 392, '怕': 393, '份': 394, '秘': 395, '去': 396, '严': 397, '感': 398, '醫': 399, '力': 400, '間': 401, '派': 402, '曲': 403, '物': 404, '得': 405, '恐': 406, '問': 407, '票': 408, '男 ...

# %%
# 利用字典，映射数据
en_num_data = [[en2id[en] for en in line] for line in en_data]
ch_num_data = [[ch2id['<GO>']] + [ch2id[ch] for ch in line] + [ch2id['<EOS>']] for line in ch_data]
de_num_data = [[ch2id[ch] for ch in line] + [ch2id['<EOS>']] for line in ch_data]

print('char:', en_data[1])
print('index:', en_num_data[1])

en_maxlength = max([len(line) for line in en_num_data])
ch_maxlength = max([len(line) for line in ch_num_data])

# 文本数据转化为数字数据
en_num_data = [data + [en2id['<PAD>']] * (en_maxlength - len(data)) for data in en_num_data]
ch_num_data = [data + [en2id['<PAD>']] * (ch_maxlength - len(data)) for data in ch_num_data]
de_num_data = [data + [en2id['<PAD>']] * (ch_maxlength - len(data)) for data in de_num_data]


# 设计数据生成器
def batch_data(en_num_data, ch_num_data, de_num_data, batch_size):
    batch_num = len(en_num_data) // batch_size
    for i in range(batch_num):
        begin = i * batch_size
        end = begin + batch_size
        x = en_num_data[begin:end]
        y = ch_num_data[begin:end]
        z = de_num_data[begin:end]
        yield x, y, z
# Out:
# char: Hi.
# index: [49, 29, 42]

# %%
import tensorflow as tf

max_encoder_seq_length = en_maxlength
max_decoder_seq_length = ch_maxlength
keepprb = 0.9

EN_VOCAB_SIZE = len(en2id)
CH_VOCAB_SIZE = len(ch2id)

HIDDEN_LAYERS = 2
HIDDEN_SIZE = 256

learning_rate = 0.003

BATCH_SIZE = 8
BATCH_NUMS = len(ch_num_data) // BATCH_SIZE
MAX_GRAD_NORM = 1

EPOCHS = 50

# %%
encoder_inputs = tf.placeholder(tf.int32, [BATCH_SIZE, max_encoder_seq_length])
decoder_inputs = tf.placeholder(tf.int32, [BATCH_SIZE, max_decoder_seq_length])
targets = tf.placeholder(tf.int32, [BATCH_SIZE, max_decoder_seq_length])
keepprb = tf.placeholder(tf.float32)


with tf.name_scope('embedding_encoder'):
	encoder_embedding = tf.get_variable('embedding_encoder', [EN_VOCAB_SIZE, HIDDEN_SIZE])
	encoder_emb = tf.nn.embedding_lookup(encoder_embedding, encoder_inputs)
	encoder_emb = tf.nn.dropout(encoder_emb, keepprb)


# encoder
with tf.variable_scope('encoder'):
	encoder_lstm = tf.contrib.rnn.LSTMCell(HIDDEN_SIZE, state_is_tuple=True)
	encoder_lstm = tf.contrib.rnn.DropoutWrapper(encoder_lstm, output_keep_prob=keepprb)
	encoder_cell = tf.contrib.rnn.MultiRNNCell([encoder_lstm] * HIDDEN_LAYERS)
	initial_state = encoder_cell.zero_state(BATCH_SIZE, tf.float32)
	_, final_state = tf.nn.dynamic_rnn(encoder_cell, encoder_emb, initial_state=initial_state)


with tf.name_scope('embedding_decoder'):
	decoder_embedding = tf.get_variable('embedding_decoder', [CH_VOCAB_SIZE, HIDDEN_SIZE])
	decoder_emb = tf.nn.embedding_lookup(decoder_embedding, decoder_inputs)
	decoder_emb = tf.nn.dropout(decoder_emb, keepprb)


# decoder
with tf.variable_scope('decoder'):
	decoder_lstm = tf.contrib.rnn.LSTMCell(HIDDEN_SIZE, state_is_tuple=True)
	decoder_lstm = tf.contrib.rnn.DropoutWrapper(decoder_lstm, output_keep_prob=keepprb)
	decoder_cell = tf.contrib.rnn.MultiRNNCell([decoder_lstm] * HIDDEN_LAYERS)
	outputs, _ = tf.nn.dynamic_rnn(decoder_cell, decoder_emb, initial_state=final_state)
	outputs = tf.reshape(tf.concat(outputs, 1), [-1, HIDDEN_SIZE])


w = tf.get_variable('outputs_weight', [HIDDEN_SIZE, CH_VOCAB_SIZE])
b = tf.get_variable('outputs_bias', [CH_VOCAB_SIZE])
logits = tf.matmul(outputs, w) + b

		# ======计算损失=======
loss = tf.contrib.legacy_seq2seq.sequence_loss_by_example([logits], [tf.reshape(targets, [-1])], 
														[tf.ones([BATCH_SIZE * max_decoder_seq_length], dtype=tf.float32)])
cost = tf.reduce_sum(loss) / BATCH_SIZE

		# =============优化算法==============
          # =============学习率衰减==============
global_step = tf.Variable(0)
learning_rate = tf.train.exponential_decay(learning_rate, global_step, BATCH_NUMS, 0.99, staircase=True)

			# =======通过clip_by_global_norm()控制梯度大小======
trainable_variables = tf.trainable_variables()
grads, _ = tf.clip_by_global_norm(tf.gradients(cost, trainable_variables), MAX_GRAD_NORM)
opt = tf.train.AdamOptimizer(learning_rate).apply_gradients(zip(grads, trainable_variables))

		# ==============预测输出=============
predict = tf.reshape(tf.argmax(logits, 1), [-1, max_decoder_seq_length])

# %%
# 保存模型
saver = tf.train.Saver()
with tf.Session() as sess:
	writer = tf.summary.FileWriter('logs/tensorboard', tf.get_default_graph())
	sess.run(tf.global_variables_initializer())
	for k in range(EPOCHS):
		total_loss = 0.
		data_generator = batch_data(en_num_data, ch_num_data, de_num_data, BATCH_SIZE)
		for i in range(BATCH_NUMS):
			en_batch, ch_batch, de_batch = next(data_generator)
			feed = {encoder_inputs: en_batch, decoder_inputs: ch_batch, targets: de_batch, keepprb: 0.8}
			costs, _ = sess.run([cost, opt], feed_dict=feed)
			total_loss += costs
			if (i+1) % 50 == 0:
				print('epochs:', k + 1, 'iter:', i + 1, 'cost:', total_loss / i + 1)
				#print('predict:', sess.run(predict[0], feed_dict=feed))
				print('text:', ''.join([id2ch[i] for i in sess.run(predict[0], feed_dict=feed) if(i != 0 and i != 1)]))
				print('label:', ''.join([id2ch[i] for i in de_batch[0] if(i != 0 and i != 1)]))
                
	saver.save(sess, './checkpoints/lstm.ckpt')

writer.close()
# Out:
# epochs: 1 iter: 50 cost: 35.808754590092875
# text: 我是。。。
# label: 开车慢点。
# epochs: 1 iter: 100 cost: 33.83278162792475
# text: 我我是。。
# label: 我很快乐。
# epochs: 2 iter: 50 cost: 24.753880987361985
# text: 我是了。。
# label: 开车慢点。
# epochs: 2 iter: 100 cost: 26.28698688083225
# text: 我是一。。
# label: 我很快乐。
# epochs: 3 iter: 50 cost: 23.512867324206294
# text: 我是。。。
# label: 开车慢点。
# epochs: 3 iter: 100 cost: 24.913117765176175
# text: 我是一。。
# label: 我很快乐。
# epochs: 4 iter: 50 cost: 22.480378520732025
# text: 我是了。。
# label: 开车慢点。
# epochs: 4 iter: 100 cost: 23.888123830159504
# text: 我是歡。。
# label: 我很快乐。
# epochs: 5 iter: 50 cost: 21.464869382430095
# text: 我是了。。
# label: 开车慢点。
# epochs: 5 iter: 100 cost: 22.81276946597629
# text: 我是一本。
# label: 我很快乐。
# epochs: 6 iter: 50 cost: 20.4119589280109
# text: 我上！。。
# label: 开车慢点。
# epochs: 6 iter: 100 cost: 21.616657054785527
# text: 我是一谎。
# label: 我很快乐。
# epochs: 7 iter: 50 cost: 19.504937133010554
# text: 你！說！。
# label: 开车慢点。
# epochs: 7 iter: 100 cost: 20.603414718550866
# text: 我們一谎。
# label: 我很快乐。
# epochs: 8 iter: 50 cost: 18.84740049011853
# text: 我心啊。。
# label: 开车慢点。
# epochs: 8 iter: 100 cost: 19.718908984251698
# text: 我是常衣。
# label: 我很快乐。
# epochs: 9 iter: 50 cost: 17.711577843646612
# text: 你擔力！。
# label: 开车慢点。
# epochs: 9 iter: 100 cost: 18.506894390992443
# text: 我不派。。
# label: 我很快乐。
# epochs: 10 iter: 50 cost: 16.986076977788187
# text: 你的說点。
# label: 开车慢点。
# epochs: 10 iter: 100 cost: 17.80779580395631
# text: 我喜一乐。
# label: 我很快乐。
# epochs: 11 iter: 50 cost: 16.232473529115016
# text: 你怪說！。
# label: 开车慢点。
# epochs: 11 iter: 100 cost: 16.714884469003387
# text: 我不快樂。
# label: 我很快乐。
# epochs: 12 iter: 50 cost: 15.070738695105728
# text: 你，歌！。
# label: 开车慢点。
# epochs: 12 iter: 100 cost: 15.725877126057943
# text: 我們待樂。
# label: 我很快乐。
# epochs: 13 iter: 50 cost: 14.637139456612724
# text: 你唱歌！。
# label: 开车慢点。
# epochs: 13 iter: 100 cost: 14.84514225853814
# text: 我喜矮语。
# label: 我很快乐。
# epochs: 14 iter: 50 cost: 13.388979989655164
# text: 你唱歌！。
# label: 开车慢点。
# epochs: 14 iter: 100 cost: 13.867433625038224
# text: 我是派樂。
# label: 我很快乐。
# epochs: 15 iter: 50 cost: 13.130592871685417
# text: 你，站点。
# label: 开车慢点。
# epochs: 15 iter: 100 cost: 13.377607682738642
# text: 我今快樂。
# label: 我很快乐。
# epochs: 16 iter: 50 cost: 12.246841187379799
# text: 你好站点。
# label: 开车慢点。
# epochs: 16 iter: 100 cost: 12.446477591389357
# text: 我是快樂。
# label: 我很快乐。
# epochs: 17 iter: 50 cost: 11.875332988038355
# text: 你，慢！。
# label: 开车慢点。
# epochs: 17 iter: 100 cost: 11.95479623717491
# text: 我喜快樂。
# label: 我很快乐。
# epochs: 18 iter: 50 cost: 11.774492254062574
# text: 你，歌！。
# label: 开车慢点。
# epochs: 18 iter: 100 cost: 11.740372484380549
# text: 我喜快樂。
# label: 我很快乐。
# epochs: 19 iter: 50 cost: 11.246199821939273
# text: 你，慢点。
# label: 开车慢点。
# epochs: 19 iter: 100 cost: 10.92947764348502
# text: 我很快樂。
# label: 我很快乐。
# epochs: 20 iter: 50 cost: 10.375667426050926
# text: 你好慢点。
# label: 开车慢点。
# epochs: 20 iter: 100 cost: 10.3896421808185
# text: 我喜快樂。
# label: 我很快乐。
# epochs: 21 iter: 50 cost: 9.797770354212547
# text: 你车慢点。
# label: 开车慢点。
# epochs: 21 iter: 100 cost: 9.834420199346061
# text: 我今激樂。
# label: 我很快乐。
# epochs: 22 iter: 50 cost: 9.464560100010463
# text: 你好慢点。
# label: 开车慢点。
# epochs: 22 iter: 100 cost: 9.453789099298342
# text: 我是激樂。
# label: 我很快乐。
# epochs: 23 iter: 50 cost: 9.230791052993464
# text: 你静怪点。
# label: 开车慢点。
# epochs: 23 iter: 100 cost: 9.139095065569636
# text: 我是快樂。
# label: 我很快乐。
# epochs: 24 iter: 50 cost: 9.33425506280393
# text: 你火慢点。
# label: 开车慢点。
# epochs: 24 iter: 100 cost: 9.365849225208013
# text: 我咳快樂。
# label: 我很快乐。
# epochs: 25 iter: 50 cost: 9.853096193196823
# text: 你过歌点。
# label: 开车慢点。
# epochs: 25 iter: 100 cost: 9.541780062396118
# text: 我有快樂。
# label: 我很快乐。
# epochs: 26 iter: 50 cost: 9.189228787714121
# text: 我火慢点。
# label: 开车慢点。
# epochs: 26 iter: 100 cost: 9.018464931333908
# text: 我喜快樂。
# label: 我很快乐。
# epochs: 27 iter: 50 cost: 8.792171896720419
# text: 你车慢点。
# label: 开车慢点。
# epochs: 27 iter: 100 cost: 8.73128143464676
# text: 我是快樂。
# label: 我很快乐。
# epochs: 28 iter: 50 cost: 9.34238776382135
# text: 你火头点。
# label: 开车慢点。
# epochs: 28 iter: 100 cost: 8.903725190596148
# text: 我喜忙樂。
# label: 我很快乐。
# epochs: 29 iter: 50 cost: 8.53705445114447
# text: 你火慢点。
# label: 开车慢点。
# epochs: 29 iter: 100 cost: 8.315767028115012
# text: 我很快樂。
# label: 我很快乐。
# epochs: 30 iter: 50 cost: 8.323231658157038
# text: 你过。点。
# label: 开车慢点。
# epochs: 30 iter: 100 cost: 8.271270800118494
# text: 我喜快樂。
# label: 我很快乐。
# epochs: 31 iter: 50 cost: 8.041095373581868
# text: 你车慢点。
# label: 开车慢点。
# epochs: 31 iter: 100 cost: 8.19058692816532
# text: 我們激乐。
# label: 我很快乐。
# epochs: 32 iter: 50 cost: 8.074925918968356
# text: 他火慢点。
# label: 开车慢点。
# epochs: 32 iter: 100 cost: 8.059135335864443
# text: 我喜忙樂。
# label: 我很快乐。
# epochs: 33 iter: 50 cost: 7.737644798901616
# text: 你车小点。
# label: 开车慢点。
# epochs: 33 iter: 100 cost: 7.724894268344147
# text: 我今快樂。
# label: 我很快乐。
# epochs: 34 iter: 50 cost: 7.52581499060806
# text: 你车慢点。
# label: 开车慢点。
# epochs: 34 iter: 100 cost: 7.646377033657497
# text: 我是快乐。
# label: 我很快乐。
# epochs: 35 iter: 50 cost: 8.242631581364845
# text: 你车慢点。
# label: 开车慢点。
# epochs: 35 iter: 100 cost: 8.094039705064562
# text: 我不忙乐。
# label: 我很快乐。
# epochs: 36 iter: 50 cost: 8.16406484526031
# text: 她车小点。
# label: 开车慢点。
# epochs: 36 iter: 100 cost: 8.133316738436921
# text: 我是忙乐。
# label: 我很快乐。
# epochs: 37 iter: 50 cost: 7.560443878173828
# text: 她车小点。
# label: 开车慢点。
# epochs: 37 iter: 100 cost: 7.8137776008760085
# text: 我是难过。
# label: 我很快乐。
# epochs: 38 iter: 50 cost: 7.178915889895692
# text: 她火小点。
# label: 开车慢点。
# epochs: 38 iter: 100 cost: 7.440878521312367
# text: 我是忙樂。
# label: 我很快乐。
# epochs: 39 iter: 50 cost: 7.1078161220161284
# text: 她车小点。
# label: 开车慢点。
# epochs: 39 iter: 100 cost: 7.270275038902206
# text: 我有好乐。
# label: 我很快乐。
# epochs: 40 iter: 50 cost: 6.788327976148956
# text: 你火慢点。
# label: 开车慢点。
# epochs: 40 iter: 100 cost: 6.966078820854727
# text: 我是冷乐。
# label: 我很快乐。
# epochs: 41 iter: 50 cost: 6.739449462112115
# text: 她车小点。
# label: 开车慢点。
# epochs: 41 iter: 100 cost: 6.961881088488029
# text: 我是好乐。
# label: 我很快乐。
# epochs: 42 iter: 50 cost: 6.448310910439004
# text: 她车慢点。
# label: 开车慢点。
# epochs: 42 iter: 100 cost: 6.692752529876401
# text: 我是好乐。
# label: 我很快乐。
# epochs: 43 iter: 50 cost: 6.391680834244709
# text: 别车小点。
# label: 开车慢点。
# epochs: 43 iter: 100 cost: 6.578833782311642
# text: 我是难乐。
# label: 我很快乐。
# epochs: 44 iter: 50 cost: 6.242744416606669
# text: 她车小点。
# label: 开车慢点。
# epochs: 44 iter: 100 cost: 6.463046131712018
# text: 我是忙乐。
# label: 我很快乐。
# epochs: 45 iter: 50 cost: 6.05380688394819
# text: 再车小点。
# label: 开车慢点。
# epochs: 45 iter: 100 cost: 6.298653966248637
# text: 我是忙樂。
# label: 我很快乐。
# epochs: 46 iter: 50 cost: 5.983971946093501
# text: 往车小点。
# label: 开车慢点。
# epochs: 46 iter: 100 cost: 6.154376374350654
# text: 我在忙乐。
# label: 我很快乐。
# epochs: 47 iter: 50 cost: 5.832778473289645
# text: 再火小点。
# label: 开车慢点。
# epochs: 47 iter: 100 cost: 6.036830788910991
# text: 我是忙过。
# label: 我很快乐。
# epochs: 48 iter: 50 cost: 5.755753468494026
# text: 赶车小点。
# label: 开车慢点。
# epochs: 48 iter: 100 cost: 5.909154578892871
# text: 我是好樂。
# label: 我很快乐。
# epochs: 49 iter: 50 cost: 5.526876868033896
# text: 往车小一。
# label: 开车慢点。
# epochs: 49 iter: 100 cost: 5.768981815588595
# text: 我是快乐。
# label: 我很快乐。
# epochs: 50 iter: 50 cost: 5.392627370600798
# text: 往车慢点。
# label: 开车慢点。
# epochs: 50 iter: 100 cost: 5.605178792067249
# text: 我是激樂。
# label: 我很快乐。
